# %% [markdown]
# # Navegación en HTML y Extracción de Tablas con BeautifulSoup

# %% [markdown]
# ## 1. Introducción a la Estructura HTML

# %% [markdown]
# Cuando cargamos una página web en un navegador, lo que realmente obtenemos es un documento **HTML**, que es el código fuente de la página.

# %% [markdown]
# ### Cómo inspeccionar el HTML de una página web:

# %% [markdown]
# 1. **Hacer clic derecho en la página → 'Inspeccionar'** (en Chrome o Firefox).

# %% [markdown]
# 2. **Ver el código fuente** con `Ctrl + U` o `Cmd + U` en Mac.

# %% [markdown]
# 3. **Escribir en la barra del navegador**: `view-source:https://en.wikipedia.org/wiki/Passengers_of_the_Titanic`.

# %% [markdown]
# ## 2. Ubicar la Tabla en el HTML

# %% [markdown]
# Si inspeccionamos la página de Wikipedia, veremos que los datos de los pasajeros están organizados en **tablas** dentro de elementos `<table>` con la clase `'wikitable sortable'`.

# %% [markdown]
# ### Ejemplo de estructura HTML de la tabla:

# %%
<table class='wikitable sortable'>
    <tr>
        <th>Name</th>
        <th>Age</th>
        <th>Class</th>
    </tr>
    <tr style='background:#9bddff;'>
        <td>John Smith</td>
        <td>30</td>
        <td>1</td>
    </tr>
</table>

# %% [markdown]
# ## 3. Cómo Extraer la Tabla con `BeautifulSoup`

# %% [markdown]
# Usamos **BeautifulSoup** para encontrar todas las tablas en la página y extraer su contenido.

# %%
import requests
from bs4 import BeautifulSoup

# URL de Wikipedia
wikipage = 'https://en.wikipedia.org/wiki/Passengers_of_the_Titanic'

# Hacer la petición HTTP
page = requests.get(wikipage)

# Parsear el contenido HTML
soup = BeautifulSoup(page.content, 'html.parser')

# Buscar todas las tablas con la clase específica
wikitables = soup.find_all('table', {'class': 'wikitable sortable'})

print(f'Se encontraron {len(wikitables)} tablas en la página.')
# Out:
# Se encontraron 3 tablas en la página.

# %%
for i, table in enumerate(wikitables):
    # Intentar obtener el título de la tabla si hay una etiqueta <caption>
    title_tag = table.find('caption')
    title = title_tag.get_text(strip=True) if title_tag else f'Tabla {i+1} (Sin título)'

    # Contar las filas de la tabla (sin incluir la fila de encabezados)
    rows = table.find_all('tr')
    num_rows = len(rows) - 1  # Restamos 1 para no contar el encabezado

    # Obtener los nombres de las columnas (th)
    headers = [header.get_text(strip=True) for header in table.find_all('th')]

    print(f'{title}')
    print(f'Número de filas: {num_rows}')
    print(f'Encabezados: {headers}\n')
# Out:
# Tabla 1 (Sin título)
# Número de filas: 326
# Encabezados: ['Name', 'Age', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body']
#
# Tabla 2 (Sin título)
# Número de filas: 278
# Encabezados: ['Name', 'Age', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body']
#
# Tabla 3 (Sin título)
# Número de filas: 707
# Encabezados: ['Name', 'age', 'Hometown', 'Home country', 'Boarded', 'Destination', 'Lifeboat', 'Body']

# %% [markdown]
# ## 4. Identificar a los Fallecidos en la Tabla (Basado en el Color)

# %% [markdown]
# Sabemos que los pasajeros fallecidos tienen `style='background:#9bddff;'`. Entonces, podemos filtrar las filas (`<tr>`) que contienen este atributo.

# %%
for i, table in enumerate(wikitables):
    print(f'\nTabla {i+1}:')

    # Extraer todas las filas que tienen el color de fallecidos
    dead_rows = table.find_all('tr', style='background:#9bddff;')

    # Extraer nombres de los fallecidos
    for row in dead_rows:
        cells = row.find_all('td')  # Obtener celdas
        if len(cells) > 1:
            name = cells[0].get_text(strip=True)
            print(f'Fallecido: {name}')
# Out:
# Tabla 1:
# Fallecido: Allen, Miss Elizabeth Walton
# Fallecido: and cook, Miss Amelia Mary "Mildred" Brown[73]
# Fallecido: and maid, Miss Sarah Daniels
# Fallecido: Allison, Master Hudson Trevor
# Fallecido: and nurse, Miss Alice Catherine Cleaver
# Fallecido: Anderson, Mr. Harry
# Fallecido: Andrews, Miss Kornelia Theodosia
# Fallecido: Appleton, Mrs. Charlotte Lane (née Lamson)
# Fallecido: Astor, Mrs. Madeleine Talmage (née Force)[75][76]
# Fallecido: and maid, Miss Rosalie Bidois
# Fallecido: and nurse, Miss Caroline Louise Endres
# Fallecido: Aubart, Mrs. Léontine Pauline[77]
# Fallecido: Barkworth, Mr. Algernon Henry Wilson
# Fallecido: Baxter, Mrs. Hélène (née de Lanaudière-Chaput)
# Fallecido: Beckwith, Mr. Richard Leonard
# Fallecido: Beckwith, Mrs. Sallie (née Monypeny)
# Fallecido: Behr, Mr. Karl Howell
# Fallecido: Bishop, Mr. Dickinson H. "Dick"
# Fallecido: Bishop, Mrs. Helen (née Walton)[76][79]
# Fallecido: Björnström-Steffansson, Mr. Mauritz Håkan
# Fallecido: Blank, Mr. Henry
# Fallecido: Bonnell, Miss Elizabeth
# Fallecido: Bonnell, Miss Caroline
# Fallecido: Bowerman, Miss Elsie Edith
# Fallecido: Brereton, Mr. George Andrew (alias George A. Brayton)
# Fallecido: Brown, Mrs. Caroline Lane (née Lamson)
# Fallecido: Brown, Mrs. Margaret (née Tobin)
# Fallecido: Bucknell, Mrs. Emma Eliza (née Ward)
# Fallecido: and maid, Miss Albina Bazzani
# Fallecido: Calderhead, Mr. Edward Pennington
# Fallecido: Candee, Mrs. Helen Churchill (née Hungerford)
# Fallecido: Cardeza, Mrs. Charlotte Wardle (née Drake)
# Fallecido: and maid, Miss Annie Moore Ward
# Fallecido: Cardeza, Mr. Thomas Drake Martinez
# Fallecido: and valet, Mr. Gustave J. Lesueur
# Fallecido: Carter, Mr. William Ernest
# Fallecido: Carter, Mrs. Lucile (née Polk)
# Fallecido: and maid, Miss Auguste Serreplan
# Fallecido: Carter, Miss Lucile Polk
# Fallecido: Carter, Master William Thornton II
# Fallecido: Cassebeer, Mrs. Eleanor Genevieve (née Fosdick)
# Fallecido: Cavendish, Mrs. Julia Florence (née Siegel)
# Fallecido: and maid, Miss Ellen "Nellie" Barber
# Fallecido: Chaffee, Mrs. Carrie Constance (née Toogood)
# Fallecido: Chambers, Mr. Norman Campbell
# Fallecido: Chambers, Mrs. Bertha (née Griggs)
# Fallecido: Cherry, Miss Gladys
# Fallecido: Chevré, Mr. Paul Romaine Marie Léonce
# Fallecido: Chibnall, Mrs. Edith Martha Bowerman (née Barber)
# Fallecido: Clark, Mrs. Virginia Estelle (née McDowell)
# Fallecido: Compton, Mrs. Mary Eliza (née Ingersoll)
# Fallecido: Compton, Miss Sara Rebecca "Sadie"
# Fallecido: Cornell, Mrs. Malvina Helen (née Lamson)
# Fallecido: Crosby, Mrs. Catherine Elizabeth (née Halstead)
# Fallecido: Crosby, Miss Harriette Rebecca
# Fallecido: Cumings, Mrs. Florence Briggs (née Thayer)
# Fallecido: Daly, Mr. Peter Dennis
# Fallecido: Daniel, Mr. Robert Williams
# Fallecido: Davidson, Mrs. Orian (née Hays)
# Fallecido: Dick, Mr. Albert Adrian
# Fallecido: Dick, Mrs. Vera (née Gillespie)
# Fallecido: Dodge, Dr. Washington
# Fallecido: Dodge, Mrs. Ruth (née Vidaver)
# Fallecido: Dodge, Master Washington, Jr.
# Fallecido: Douglas, Mrs. Mahala (née Dutton)
# Fallecido: and maid, Miss Berthe Leroy
# Fallecido: Douglas, Mrs. Mary Hélène (née Baxter)
# Fallecido: Duff Gordon, Sir Cosmo Edmund
# Fallecido: Duff Gordon, Lucy Christiana, Lady (née Sutherland)
# Fallecido: and secretary, Miss Laura Mabel Francatelli
# Fallecido: Eustis, Miss Elizabeth Mussey
# Fallecido: Flegenheim, Mrs. Antoinette "Tony" (née Wendt)
# Fallecido: Flynn, Mr. John Irwin
# Fallecido: Fortune, Mrs. Mary (née McDougald)
# Fallecido: Fortune, Miss Ethel Flora
# Fallecido: Fortune, Miss Alice Elizabeth
# Fallecido: Fortune, Miss Mabel Helen
# Fallecido: Frauenthal, Dr. Henry William
# Fallecido: Frauenthal, Mrs. Clara (née Heinsheimer)
# Fallecido: Frauenthal, Mr. Isaac Gerald
# Fallecido: Frölicher, Mr. Maximilian Josef
# Fallecido: Frölicher, Mrs. Margaretha Emerentia (née Stehli)
# Fallecido: Frölicher-Stehli, Miss Hedwig Margaritha
# Fallecido: Futrelle, Mrs. Lily May (née Peel)
# Fallecido: Gibson, Mrs. Pauline Caroline (née Boeson)
# Fallecido: Gibson, Miss Dorothy Winifred
# Fallecido: Goldenberg, Mr. Samuel L.
# Fallecido: Goldenberg, Mrs. Nella (née Wiggins)
# Fallecido: Gracie IV, Colonel Archibald
# Fallecido: Graham, Mrs. Edith Ware (née Junkins)
# Fallecido: Graham, Miss Margaret Edith
# Fallecido: and governess, Miss Elizabeth Weed Shutes
# Fallecido: Greenfield, Mrs. Blanche (née Strouse)
# Fallecido: Greenfield, Mr. William Bertram
# Fallecido: Harder, Mr. George Achilles
# Fallecido: Harder, Mrs. Dorothy (née Annan)
# Fallecido: Harper, Mr. Henry Sleeper
# Fallecido: and dragoman, Mr. Hammad Hassab
# Fallecido: Harper, Mrs. Myra Raymond (née Haxtun)
# Fallecido: Harris, Mrs. Irene "Renee" (née Wallach)
# Fallecido: Hawksford, Mr. Walter James
# Fallecido: Hays, Mrs. Clara Jennings (née Grigg)
# Fallecido: and maid, Miss Mary Anne Perreault
# Fallecido: Hays, Miss Margaret Bechstein
# Fallecido: Hippach, Mrs. Ida Sophia (née Fischer)
# Fallecido: Hippach, Miss Jean Gertrude
# Fallecido: Hogeboom, Mrs. Anna Louisa (née Andrews)
# Fallecido: Holverson, Mrs. Mary Aline (née Towner)
# Fallecido: Homer, Mr. Harry (alias E. Haven)
# Fallecido: Hoyt, Mr. Frederick Maxfield
# Fallecido: Hoyt, Mrs. Jane Anne (née Forby)
# Fallecido: Ismay, Mr. Joseph Bruce
# Fallecido: Kenyon, Mrs. Marion (née Stauffer)[76][82]
# Fallecido: Kimball, Mr. Edwin Nelson Jr.
# Fallecido: Kimball, Mrs. Gertrude (née Parsons)
# Fallecido: Leader, Dr. Alice (née Farnham)
# Fallecido: Leslie, Lucy Noël Martha, Countess of Rothes (née Dyer-Edwardes)
# Fallecido: and maid, Miss Roberta Elizabeth Mary "Cissy" Maioni[83]
# Fallecido: Lindström, Mrs. Sigrid (née Posse)
# Fallecido: Lines, Mrs. Elizabeth Lindsey (née James)
# Fallecido: Lines, Miss Mary Conover
# Fallecido: Longley, Miss Gretchen Fiske
# Fallecido: Madill, Miss Georgette Alexandra
# Fallecido: Maréchal, Mr. Pierre, Sr.
# Fallecido: Marvin, Mrs. Mary Graham Carmichael (née Farquarson)[76][84]
# Fallecido: Mayné, Miss Bertha Antonine
# Fallecido: McGough, Mr. James Robert
# Fallecido: Meyer, Mrs. Leila (née Saks)
# Fallecido: Minahan, Mrs. Lillian E. (née Thorpe)
# Fallecido: Minahan, Miss Daisy E.
# Fallecido: Mock, Mr. Philipp Edmund
# Fallecido: Newell, Miss Madeleine
# Fallecido: Newell, Miss Marjorie Anne
# Fallecido: Newsom, Miss Helen Monypeny
# Fallecido: Nourney, Mr. Alfred[85][86]
# Fallecido: Omont, Mr. Alfred Fernand
# Fallecido: Ostby, Miss Helene Ragnhild
# Fallecido: Pears, Mrs. Edith (née Wearne)
# Fallecido: Peñasco y Castellana, Mrs. Maria Josefa (née Perez de Soto y Vallejo)
# Fallecido: and maid, Doña Fermina Oliva y Ocana
# Fallecido: Peuchen, Major Arthur Godfrey
# Fallecido: Potter, Mrs. Lily Alexenia (née Wilson)
# Fallecido: Rheims, Mr. George Alexander Lucien
# Fallecido: Robert, Mrs. Elisabeth Walton (née McMillan)
# Fallecido: and maid, Miss Emilie Kreuchen
# Fallecido: Romaine, Mr. Charles Hallance (alias C. Rolmane)
# Fallecido: Rosenbaum, Miss Edith Louise
# Fallecido: Rothschild, Mrs. Elizabeth Jane Anne (née Barrett)
# Fallecido: Ryerson, Mrs. Emily Maria (née Borie)
# Fallecido: and maid, Miss Victorine Chaudanson
# Fallecido: Ryerson, Miss Susan Parker "Suzette"
# Fallecido: Ryerson, Miss Emily Borie
# Fallecido: Ryerson, Master John Borie "Jack"
# Fallecido: and governess, Miss Grace Scott Bowen
# Fallecido: Saalfeld, Mr. Adolphe
# Fallecido: Salomon, Mr. Abraham Lincoln
# Fallecido: Schabert, Mrs. Emma Mary Blake (née Mock)
# Fallecido: Seward, Mr. Frederic Kimber
# Fallecido: Silverthorne, Mr. Spencer Victor
# Fallecido: Silvey, Mrs. Alice (née Munger)
# Fallecido: Simonius-Blumer, Colonel Alfons
# Fallecido: Sloper, Mr. William Thompson
# Fallecido: Smith, Mrs. Mary Eloise (née Hughes)[76][87]
# Fallecido: Snyder, Mr. John Pillsbury
# Fallecido: Snyder, Mrs. Nellie (née Stevenson)
# Fallecido: Spedden, Mr. Frederic Oakley
# Fallecido: Spedden, Mrs. Margaretta Corning (née Stone)
# Fallecido: and maid, Miss Helen Alice Wilson
# Fallecido: Spedden, Master Robert Douglas
# Fallecido: and nurse, Miss Elizabeth Margaret Burns
# Fallecido: Spencer, Mrs. Marie Eugénie (née Demougeot)
# Fallecido: and maid, Miss Eugenie Elise Lurette
# Fallecido: Stähelin-Maeglin, Dr. Max
# Fallecido: Stengel, Mr. Charles Emil Henry
# Fallecido: Stengel, Mrs. Annie May (née Morris)
# Fallecido: Stephenson, Mrs. Martha (née Eustis)
# Fallecido: Stone, Mrs. Martha Evelyn (née Stevens)
# Fallecido: and maid, Miss Amelie "Amelia" Icard
# Fallecido: and maid, Miss Ellen Bird
# Fallecido: Swift, Mrs. Margaret Welles (née Barron)
# Fallecido: Taussig, Mrs. Tillie (née Mandelbaum)
# Fallecido: Taussig, Miss Ruth
# Fallecido: Taylor, Mr. Elmer Zebley
# Fallecido: Thayer, Mrs. Marian Longsteth(née Morris)
# Fallecido: and maid, Miss Margaret Fleming
# Fallecido: Thayer, Mr. John Borland "Jack" III
# Fallecido: Thorne, Mrs. Gertrude Maybelle (née McMinn)
# Fallecido: Tucker, Mr. Gilbert Milligan Jr.
# Fallecido: Warren, Mrs. Anna Sophia (née Atkinson)
# Fallecido: White, Mrs. Ella (née Holmes)
# Fallecido: and maid, Miss Amelia Mayo "Nellie" Bessette
# Fallecido: Wick, Mrs. Mary (née Hitchcock)
# Fallecido: Wick, Miss Mary Natalie
# Fallecido: Widener, Mrs. Eleanor (née Elkins)
# Fallecido: and maid, Miss Amalie Henriette "Emily" Gieger
# Fallecido: Willard, Miss Constance
# Fallecido: Williams, Mr. Richard Norris II
# Fallecido: Woolner, Mr. Hugh
# Fallecido: Young, Miss Marie Grice
#
# Tabla 2:
# Fallecido: Abelson, Mrs. Anna (née Wizosky?)
# Fallecido: Angle, Mrs. Florence Agnes "Mary" (née Hughes)
# Fallecido: Ball, Mrs. Ada E. (née Hall)
# Fallecido: Beane, Mr. Edward
# Fallecido: Beane. Mrs. Ethel (née Clarke)
# Fallecido: Becker, Mrs. Nellie E. (née Baumgardner)
# Fallecido: Becker, Miss Ruth Elizabeth
# Fallecido: Becker, Miss Marion Louise
# Fallecido: Becker, Master Richard Frederick
# Fallecido: Beesley, Mr. Lawrence
# Fallecido: Bentham, Miss Lillian W.
# Fallecido: Brown, Mrs. Elizabeth Catherine (née Ford)
# Fallecido: Brown, Miss Edith Eileen
# Fallecido: Bryhl, Miss Dagmar Jenny Ingeborg
# Fallecido: Buss, Miss Kate
# Fallecido: Byström, Miss Karolina
# Fallecido: Caldwell, Mr. Albert Francis
# Fallecido: Caldwell, Mrs. Sylvia Mae (née Harbaugh)
# Fallecido: Caldwell, Master Alden Gates
# Fallecido: Cameron, Miss Clear Annie
# Fallecido: Christy, Mrs. Alice Frances
# Fallecido: Christy, Miss Rachel Julie Cohen
# Fallecido: Clarke, Mrs. Ada Maria
# Fallecido: Collett, Mr. Sidney Clarence Stuart
# Fallecido: Collyer, Mrs. Charlotte Annie (née Tate)
# Fallecido: Collyer, Miss Marjorie Charlotte "Lottie"
# Fallecido: Cook, Mrs. Selena (née Rogers)
# Fallecido: Davies, Mrs. Elizabeth Agnes Mary (née White)
# Fallecido: Davies, Master John Morgan Jr.
# Fallecido: Davis, Miss Mary
# Fallecido: del Carlo, Mrs. Argene (née Genovesi)[76][88]
# Fallecido: Doling, Mrs. Ada Julia (née Bone)
# Fallecido: Doling, Miss Elsie
# Fallecido: Drew, Mrs. Lulu Thorne (née Christian)
# Fallecido: Drew, Master Marshall Brines
# Fallecido: Duran y More, Miss Florentina
# Fallecido: Duran y More, Miss Asunción
# Fallecido: Garside, Miss Ethel
# Fallecido: Hämäläinen, Mrs. Anna (Anna Hamlin)
# Fallecido: Hämäläinen, Master Viljo Unto Johannes (William Hamlin)
# Fallecido: Harper, Miss Annie Jessie "Nina"
# Fallecido: Harris, Mr. George
# Fallecido: Hart, Mrs. Esther Ada (née Bloomfield)
# Fallecido: Hart, Miss Eva Miriam
# Fallecido: Herman, Mrs. Jane (née Laver)
# Fallecido: Herman, Miss Alice
# Fallecido: Hewlett, Mrs. Mary Dunbar (née Kingcome)
# Fallecido: Hocking, Mrs. Elizabeth "Eliza" (née Neads)
# Fallecido: Hocking, Miss Ellen "Nellie"
# Fallecido: Hold, Mrs. Annie Margaret (née Hill)
# Fallecido: Hosono, Mr. Masabumi
# Fallecido: Ilett, Miss Bertha
# Fallecido: Jacobsohn, Mrs. Amy Frances Christy (née Cohen)
# Fallecido: Jerwan, Mrs. Marie Marthe (née Thuillard)
# Fallecido: Kantor, Mrs. Miriam (née Sternin)
# Fallecido: Keane, Miss Nora Agnes
# Fallecido: Kelly, Miss Florence "Fannie"
# Fallecido: Laroche, Mrs. Juliette Marie Louise (née Lafargue)[76][89]
# Fallecido: Laroche, Miss Simone Marie Anne Andrée
# Fallecido: Laroche, Miss Louise Marguerite
# Fallecido: Lehmann, Miss Bertha
# Fallecido: Leitch, Miss Jessie Wills
# Fallecido: Lemore, Mrs. Amelia "Milley" (née Hunt)
# Fallecido: Louch, Mrs. Alice Adelaide (née Slow)
# Fallecido: Mallet, Mrs. Antoinette Marie (née Magnin)
# Fallecido: Mallet, Master André Clément
# Fallecido: Mellinger, Mrs. Elizabeth Anne (née Maidment)
# Fallecido: Mellinger, Miss Madeleine Violet
# Fallecido: Mellors, Mr. William John
# Fallecido: Nassr Allah, Mrs. Adal (née Akim)[76][91]
# Fallecido: Navratil, Master Michel Marcel(alias John Hoffman)[92]
# Fallecido: Navratil, Master Edmond Roger (alias Fred Hoffman)[93]
# Fallecido: Nye, Mrs. Elizabeth (née Ramell)
# Fallecido: Oxenham, Mr. Percy Thomas
# Fallecido: Padron Manent, Mr. Julian
# Fallecido: Pallas y Castello, Mr. Emilio
# Fallecido: Parrish, Mrs. Lutie Davis (née Temple)
# Fallecido: Phillips, Miss Alice Frances Louisa
# Fallecido: Phillips, Miss Kate Florence (alias Mrs. Kate Marshall)[8][94]
# Fallecido: Pinsky, Mrs. Rosa
# Fallecido: Portaluppi, Mr. Emilio Ilario Giuseppe
# Fallecido: Quick, Mrs. Jane (née Richards)
# Fallecido: Quick, Miss Winnifred Vera
# Fallecido: Quick, Miss Phyllis May
# Fallecido: Renouf, Mrs. Lillian "Lily" (née Jefferys)
# Fallecido: Reynaldo, Miss Encarnación
# Fallecido: Richards, Mrs. Emily (née Hocking)
# Fallecido: Richards, Master William Rowe
# Fallecido: Richards, Master Sibley George
# Fallecido: Ridsdale, Miss Lucy
# Fallecido: Rugg, Miss Emily
# Fallecido: Shelley, Mrs. Imanita (née Parrish Hall)
# Fallecido: Silvén, Miss Lyyli Karolina
# Fallecido: Sincock, Miss Maude
# Fallecido: Sinkkonen, Miss Anna
# Fallecido: Sjöstedt, Mr. Ernst Adolf
# Fallecido: Slayter, Miss Hilda Mary
# Fallecido: Smith, Miss Marion Elsie
# Fallecido: Toomey, Miss Ellen Mary
# Fallecido: Trout, Mrs. Jessie L.
# Fallecido: Troutt, Miss Edwina Celia "Winnie"
# Fallecido: Wallcroft, Miss Ellen "Nellie"
# Fallecido: Ware, Mrs. Florence Louise (née Long)
# Fallecido: Watt, Mrs. Elizabeth Inglis "Bessie" (née Milne)
# Fallecido: Watt, Miss Robertha Josephine "Bertha"
# Fallecido: Webber, Miss Susan
# Fallecido: Weisz, Mrs. Mathilde Françoise (née Pëde)
# Fallecido: Wells, Mrs. Addie Dart (née Trevaskis)
# Fallecido: Wells, Miss Joan
# Fallecido: Wells, Master Ralph Lester
# Fallecido: West, Mrs. Ada Mary (née Worth)[76][95]
# Fallecido: West, Miss Constance Mirium
# Fallecido: West, Miss Barbara Joyce
# Fallecido: Whilems, Mr. Charles
# Fallecido: Wilkinson, Miss Elizabeth Anne (alias Mrs. Elizabeth Faunthorpe)
# Fallecido: Williams, Mr. Charles Eugene
# Fallecido: Wright, Miss Marion
#
# Tabla 3:
# Fallecido: Abbott, Mrs. Rhoda Mary (née Hunt)
# Fallecido: Abelseth, Miss Karen Marie
# Fallecido: Abelseth, Mr. Olaus Jørgensen
# Fallecido: Abrahamsson, Mr. Abraham August Johannes
# Fallecido: Abrahim, Mrs. Mary Sophie Halaut (née Easu)
# Fallecido: Aks, Mrs. Leah (née Rosen)
# Fallecido: Aks, Master Frank Philip
# Fallecido: Al-Muna, Mr. Nasif Qasim
# Fallecido: Al-Zainni, Mr. Fahim Ruhanna
# Fallecido: Andersen-Jensen, Miss Carla Christine
# Fallecido: Andersson, Miss Erna Alexandra
# Fallecido: Asplund, Mrs. Selma Augusta Emilia (née Johansson)
# Fallecido: Asplund, Miss Lillian Gertrud
# Fallecido: Asplund, Master Edvin Rojj Felix
# Fallecido: Asplund, Mr. Johan Charles
# Fallecido: Assaf, Mrs. Mariyam (née Khalil)
# Fallecido: Ayyub Dahir, Miss Bannurah
# Fallecido: Backström, Mrs. Maria Mathilda (née Gustafsson)[76][96]
# Fallecido: Badman, Miss Emily Louisa
# Fallecido: Banski, Mrs. Mara (née Osman)
# Fallecido: Baqlini, Mrs. Mariyam Latifa (née Qurban)
# Fallecido: Baqlini, Miss Mariya Katarin
# Fallecido: Baqlini, Miss Eujini
# Fallecido: Baqlini, Miss Hileni Barbarah
# Fallecido: Bradley, Miss Bridget Delia
# Fallecido: Buckley, Mr. Daniel
# Fallecido: Butrus-Youssef, Mrs. Katarin (née Rizk)
# Fallecido: Butrus-Youssef, Master Makhkhul
# Fallecido: Butrus-Youssef, Miss Marianna
# Fallecido: Chang, Mr. Chip
# Fallecido: Cheong, Mr. Foo
# Fallecido: Cohen, Mr. Gershon "Gus"
# Fallecido: Connolly, Miss Katherine "Kate"
# Fallecido: Corr, Miss Helen
# Fallecido: Coutts, Mrs. Mary Winnie (née Trainer)
# Fallecido: Coutts, Master William Loch "Willie"
# Fallecido: Coutts, Master Neville Leslie
# Fallecido: Cribb, Miss Laura Mae
# Fallecido: Dahl, Mr. Charles Edwart
# Fallecido: Daly, Miss Margaret "Maggie"
# Fallecido: Daly, Mr. Eugene Patrick
# Fallecido: Davison, Mrs. Mary Elizabeth
# Fallecido: De Messemaeker, Mr. Guillaume Joseph
# Fallecido: De Messemaeker, Mrs. Anna (née de Becker)
# Fallecido: de Mulder, Mr. Theodoor
# Fallecido: Dean, Mrs. Eva Georgetta (née Light)
# Fallecido: Dean, Master Bertram Vere
# Fallecido: Dean, Miss Elizabeth Gladys "Millvina"
# Fallecido: Devaney, Miss Margaret Delia
# Fallecido: Dorking, Mr. Edward Arthur
# Fallecido: Dowdell, Miss Elizabeth
# Fallecido: Dropkin, Miss Jennie
# Fallecido: Duquemin, Mr. Joseph Pierre
# Fallecido: Dyker, Mrs. Anna Elisabeth Judith (née Andersson)
# Fallecido: Emanuel, Miss Virginia Ethel
# Fallecido: Finoli, Mr. Luigi
# Fallecido: Gilnagh, Miss Mary Katherine "Katie"
# Fallecido: Glynn, Miss Mary Agatha
# Fallecido: Goldsmith, Mrs. Emily Alice (née Brown)
# Fallecido: Goldsmith, Master Frank John William
# Fallecido: Hakkarainen, Mrs. Elin Matilda (née Dolck)
# Fallecido: Hanna, Mr. Borak Suleiman
# Fallecido: Hansen, Mrs. Jennie Louise (née Howard)
# Fallecido: Healy, Miss Hanora (Nora)
# Fallecido: Hedman, Mr. Oskar Arvid
# Fallecido: Hegarty, Miss Hanora "Nora"
# Fallecido: Heikkinen, Miss Laina
# Fallecido: Hellström, Miss Hilda Maria
# Fallecido: Hirvonen, Mrs. Helga Elisabeth (née Lindqvist)
# Fallecido: Hirvonen, Miss Hildur Elisabeth
# Fallecido: Honkanen, Miss Eliina
# Fallecido: Howard, Miss May Elizabeth
# Fallecido: Hyman, Mr. Solomon Abraham
# Fallecido: Jalševac, Mr. Ivan
# Fallecido: Jansson, Mr. Carl Olof
# Fallecido: Jermyn, Miss Annie Jane
# Fallecido: Jirjis, Mrs. Shaniini (née Whabee Abi-Saab)
# Fallecido: Johannesen, Mr. Bernt Johannes
# Fallecido: Johansson Palmquist, Mr. Oskar Leander
# Fallecido: Johnson, Mrs. Elisabeth Vilhelmina (née Berg)
# Fallecido: Johnson, Master Harold Theodor
# Fallecido: Johnson, Miss Eleanor Ileen
# Fallecido: Jonsson, Mr. Carl
# Fallecido: Jussila, Mr. Eiriik
# Fallecido: Karlsson, Mr. Einar Gervasius
# Fallecido: Karun, Mr. Franz
# Fallecido: Karun, Miss Manca ("Anna")
# Fallecido: Kelly, Miss Anna Katherine
# Fallecido: Kelly, Miss Mary
# Fallecido: Kennedy, Mr. John Joseph
# Fallecido: Kink, Mr. Anton
# Fallecido: Kink, Mrs. Luise (née Heilmann)
# Fallecido: Kink, Miss Luise Gretchen
# Fallecido: Krekorian, Mr. Neshan
# Fallecido: Lam, Mr. Ali
# Fallecido: Landergren, Miss Aurora Adelia
# Fallecido: Lang, Mr. Fang
# Fallecido: Lee, Mr. Bing
# Fallecido: Lindqvist, Mr. Eino William
# Fallecido: Lulić, Mr. Nikola
# Fallecido: Lundström, Mr. Thure Edvin
# Fallecido: Madigan, Miss Margaret "Maggie"
# Fallecido: Madsen, Mr. Fridtjof Arne
# Fallecido: Mamee, Mr. Hanna
# Fallecido: Mannion, Miss Margaret
# Fallecido: McCarthy, Miss Catherine "Katie"
# Fallecido: McCormack, Mr. Thomas Joseph
# Fallecido: McCoy, Miss Catherine Agnes
# Fallecido: McCoy, Miss Alice
# Fallecido: McCoy, Mr. Bernard
# Fallecido: McDermott, Miss Bridget Delia
# Fallecido: McGovern, Miss Mary
# Fallecido: McGowan, Miss Anna F. "Annie"
# Fallecido: Midtsjø, Mr. Karl Albert
# Fallecido: Mockler, Miss Ellen Mary
# Fallecido: Moor, Mrs. Beila
# Fallecido: Moor, Master Meier
# Fallecido: Moran, Miss Bertha Bridget
# Fallecido: Moss, Mr. Albert Johan
# Fallecido: Moussa, Mrs. Mantoura
# Fallecido: Mubarik, Mrs. Amanah Fa'ud (née Iskandar)
# Fallecido: Mubarik, Master Gerios
# Fallecido: Mubarik, Master Halim Gonios
# Fallecido: Mullen, Miss Katherine "Katie"
# Fallecido: Mulvihill, Miss Bridget Elizabeth "Bertha"
# Fallecido: Murphy, Miss Catherine "Kate"
# Fallecido: Murphy, Miss Margaret Jane "Maggie/Mary"
# Fallecido: Murphy, Miss Nora
# Fallecido: Muslamani, Mrs. Fatimah
# Fallecido: Nackid, Mr. Sahid
# Fallecido: Nackid, Miss Waika "Mary" (née Mowad)
# Fallecido: Nackid, Miss Maria
# Fallecido: Nilsson, Miss Berta Olivia
# Fallecido: Nilsson, Miss Helmina Josefina
# Fallecido: Niqula-Yarid, Miss Jamilah
# Fallecido: Niqula-Yarid, Master Ilyas
# Fallecido: Niskanen, Mr. Juha
# Fallecido: Nysten, Miss Anna Sofia
# Fallecido: O'Brien, Mrs. Johanna "Hannah" (née Godfrey)
# Fallecido: O'Driscoll, Miss Bridget
# Fallecido: O'Dwyer, Miss Ellen "Nellie"
# Fallecido: O'Keefe, Mr. Patrick
# Fallecido: O'Leary, Miss Hanora "Nora"
# Fallecido: Öhman, Miss Velin
# Fallecido: Olsen, Master Arthur Carl
# Fallecido: Olsson, Mr. Oskar Wilhelm
# Fallecido: Persson, Mr. Ernst Ulrik
# Fallecido: Pickard, Mr. Berk (Trembisky)
# Fallecido: Riordan, Miss Hannah
# Fallecido: Roth, Miss Sarah A.
# Fallecido: Ryan, Mr. Edward
# Fallecido: Salkjelsvik, Miss Anna Kristine
# Fallecido: Sandström, Mrs. Agnes Charlotta (née Bengtsson)
# Fallecido: Sandström, Miss Marguerite Rut
# Fallecido: Sandström, Miss Beatrice Irene
# Fallecido: Sap, Mr. Julius (Jules)
# Fallecido: Scheerlinck, Mr. Jean Baptiste
# Fallecido: Shine, Miss Ellen Natalia
# Fallecido: Sjöblom, Miss Anna Sofiia
# Fallecido: Smyth, Miss Julia
# Fallecido: Stanley, Miss Amy Zillah Elsie
# Fallecido: Strandén, Mr. Juho Niilonpoika
# Fallecido: Sunderland, Mr. Victor Francis
# Fallecido: Sundman, Mr. Johan Julian
# Fallecido: Svensson, Mr. Johan Cervin
# Fallecido: Tenglin, Mr. Gunnar Isidor
# Fallecido: Tannous, Mrs. Thamini Khoury Fa'ud "Thelma"
# Fallecido: Tannous, Master As'ad Iskandar Fa'ud
# Fallecido: Thorneycroft, Mrs. Florence Kate (née Stears)
# Fallecido: Törnquist, Mr. William Henry
# Fallecido: Touma, Mrs. Hanna Youssef (née Razi)
# Fallecido: Touma, Miss Marianna Youssef
# Fallecido: Touma, Master Gerios (George) Youssef
# Fallecido: Turja, Miss Anna Sofiia
# Fallecido: Turkula, Mrs. Hedvig
# Fallecido: Vartanian, Mr. Davit
# Fallecido: Wennerström, Mr. August Edvard Andersson
# Fallecido: Wilkes, Mrs. Ellen
# Fallecido: Yasbak, Mrs. Silanah Fa'ud (née Iskandar)
# Fallecido: Zajib Qiyamah, Miss Adal "Jane"

# %% [markdown]
# ## 5. Construcción de un DataFrame con Pandas

# %% [markdown]
# Podemos extraer la información y almacenarla en un **DataFrame de Pandas** para un análisis más profundo.

# %% [markdown]
# ### Código:

# %%
import pandas as pd

# Lista para almacenar pasajeros
passengers = []

# Iteramos sobre cada tabla encontrada
for i, table in enumerate(wikitables):
    passenger_class = i + 1  # Primera tabla es 1ª clase, segunda es 2ª, etc.

    # Filtrar filas según el color de fondo
    dead_rows = table.find_all('tr', style='background:#9bddff;')
    all_rows = table.find_all('tr')

    # Identificar filas de personas vivas (sin estilo)
    living_rows = [row for row in all_rows if row not in dead_rows]

    # Procesar filas
    for rows, survived in [(living_rows, 1), (dead_rows, 0)]:
        for row in rows:
            cells = row.find_all('td')
            if len(cells) < 2:
                continue  # Saltamos filas sin datos

            name = cells[0].get_text(strip=True)
            age = cells[1].get_text(strip=True) if cells[1].get_text(strip=True) else None

            passengers.append({'name': name, 'class': passenger_class, 'age': age, 'survived': survived})

# Convertir a DataFrame
df_passengers = pd.DataFrame(passengers)

# Mostrar los primeros datos
print(df_passengers.head())
# Out:
#                                        name  class age  survived
# 0             Allison, Mr. Hudson Creighton      1  30         1
# 1                      Mr. George Swane[73]      1  19         1
# 2  Allison, Mrs. Bessie Waldo (née Daniels)      1  25         1
# 3               Allison, Miss Helen Loraine      1   2         1
# 4                   Andrews, Mr. Thomas[74]      1  39         1
